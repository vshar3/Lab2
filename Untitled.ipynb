# %%
import pandas as ds 
# %matplotlib inline

# %%
t = ds.read_csv("train.csv")

# %%
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
t.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, dtype: int64

# %%
t.describe()
# Out:
# C:\Users\abcd\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %%
#Histogram for variable passenger id
t.PassengerId.hist()

# %%
t.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
t[t.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Histogram For survived variable
t.Survived.hist()

# %%
#Bar Plot For Variable Survived
t.Survived.value_counts().plot(kind='bar')

# %%
t.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
t[t.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
t.Pclass.value_counts().plot(kind='bar')

# %%
#  Number of passenger Survived or not survived for pclass 3
t[t.Pclass == 3].Survived.value_counts()
# Out:
# 0    372
# 1    119
# Name: Survived, dtype: int64

# %%
#bar plot for Plcass 3
t[t.Pclass == 3].Survived.value_counts().plot(kind='bar',title="Pclass 3")

# %%
t[t.Pclass == 2].Survived.value_counts()
# Out:
# 0    97
# 1    87
# Name: Survived, dtype: int64

# %%
t[t.Pclass == 2].Survived.value_counts().plot(kind='bar',title="Pclass 2")

# %%
t[t.Pclass == 1].Survived.value_counts()
# Out:
# 1    136
# 0     80
# Name: Survived, dtype: int64

# %%
t[t.Pclass == 1].Survived.value_counts().plot(kind='bar',title="Pclass 1")

# %%
t.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
t[t.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
t[t.Sex=="male"].Survived.value_counts()
# Out:
# 0    468
# 1    109
# Name: Survived, dtype: int64

# %%
t[t.Sex=="male"].Survived.value_counts().plot(kind="barh",title="Male")

# %%
t[t.Sex=="female"].Survived.value_counts()
# Out:
# 1    233
# 0     81
# Name: Survived, dtype: int64

# %%
t[t.Sex=="female"].Survived.value_counts().plot(kind="barh",title="female")

# %%
t.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
# 30.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 27.00    18
# 35.00    18
# 26.00    18
# 32.00    18
# 31.00    17
# 16.00    17
# 23.00    15
# 20.00    15
# 34.00    15
# 33.00    15
# 39.00    14
# 17.00    13
# 40.00    13
# 42.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 48.00     9
#          ..
# 0.83      2
# 0.75      2
# 64.00     2
# 30.50     2
# 32.50     2
# 70.00     2
# 71.00     2
# 45.50     2
# 40.50     2
# 63.00     2
# 59.00     2
# 57.00     2
# 55.00     2
# 28.50     2
# 24.50     1
# 0.92      1
# 0.67      1
# 34.50     1
# 55.50     1
# 36.50     1
# 23.50     1
# 12.00     1
# 20.50     1
# 0.42      1
# 80.00     1
# 74.00     1
# 70.50     1
# 66.00     1
# 53.00     1
# 14.50     1
# Name: Age, dtype: int64

# %%
t.describe()
# Out:
# C:\Users\abcd\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %%
t[t.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
#Histogram for variable age
t.Age.hist()

# %%
meage = t.Age.min()

# %%
t.Age=t.Age.fillna(value=meage)

# %%
t[t.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#plot after replacing Null value
t.Age.hist()

# %%
t.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
t[t.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
t.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   23.882727    0.523008
# std     257.353842    0.486592    0.836071   17.483538    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000    6.000000    0.000000
# 50%     446.000000    0.000000    3.000000   24.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Histogram for variable SibSp
t.SibSp.hist()

# %%
t.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
#min: 0
#max: 6
#mean: 0.381593714927
#std: 0.80605722113

# %%
#Histogram for Parch
t.Parch.hist()

# %%
t[t.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
t.Ticket.value_counts()
# Out:
# 1601                 7
# 347082               7
# CA. 2343             7
# 347088               6
# CA 2144              6
# 3101295              6
# S.O.C. 14879         5
# 382652               5
# LINE                 4
# 113760               4
# 4133                 4
# PC 17757             4
# 19950                4
# 349909               4
# 17421                4
# 113781               4
# 2666                 4
# W./C. 6608           4
# 347077               4
# 371110               3
# 24160                3
# C.A. 31921           3
# 29106                3
# 248727               3
# 110413               3
# C.A. 34651           3
# PC 17572             3
# F.C.C. 13529         3
# PC 17755             3
# 110152               3
#                     ..
# C.A. 24580           1
# C.A. 29566           1
# 11813                1
# A/5 3902             1
# 345763               1
# 234604               1
# 350029               1
# PC 17592             1
# 14313                1
# ...

# %%
#Finding Null value for variablw Ticket
t[t.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Bar for Variable Ticket
t.Ticket.value_counts().plot(kind='bar')

# %%
#pclass3

t[t.Pclass==3].Ticket.value_counts()
# Out:
# 1601                7
# 347082              7
# CA. 2343            7
# 3101295             6
# CA 2144             6
# 347088              6
# 382652              5
# 347077              4
# W./C. 6608          4
# LINE                4
# 4133                4
# 2666                4
# 349909              4
# 363291              3
# 345773              3
# 347742              3
# 371110              3
# 392096              2
# 370129              2
# 2668                2
# 370365              2
# STON/O2. 3101279    2
# 3101278             2
# C.A. 2673           2
# 347054              2
# A/4 48871           2
# C.A. 37671          2
# 2653                2
# 364849              2
# 364516              2
#                    ..
# PP 4348             1
# 349245              1
# 347061              1
# 312991              1
# 349206              1
# 350035              1
# A/S 2816            1
# 342826              1
# 2697                1
# 2667                1
# ...

# %%
#Pclass2

t[t.Pclass==2].Ticket.value_counts()
# Out:
# S.O.C. 14879        5
# 29106               3
# C.A. 34651          3
# 239853              3
# SC/Paris 2123       3
# C.A. 31921          3
# 230080              3
# 248727              3
# F.C.C. 13529        3
# P/PP 3381           2
# 239865              2
# S.O./P.P. 3         2
# 220845              2
# 250644              2
# 231919              2
# 230136              2
# 29750               2
# C.A. 33112          2
# 244367              2
# 243847              2
# 28403               2
# 230433              2
# 2908                2
# 250649              2
# 248738              2
# 250647              2
# S.C./PARIS 2079     2
# 237736              2
# 11668               2
# 31027               2
#                    ..
# 2926                1
# 28220               1
# 220367              1
# 27849               1
# 240929              1
# 27267               1
# 29751               1
# C.A. 29566          1
# 236852              1
# 250652              1
# ...

# %%
#Pclass1

t[t.Pclass==3].Ticket.value_counts()
# Out:
# 1601                7
# 347082              7
# CA. 2343            7
# 3101295             6
# CA 2144             6
# 347088              6
# 382652              5
# 347077              4
# W./C. 6608          4
# LINE                4
# 4133                4
# 2666                4
# 349909              4
# 363291              3
# 345773              3
# 347742              3
# 371110              3
# 392096              2
# 370129              2
# 2668                2
# 370365              2
# STON/O2. 3101279    2
# 3101278             2
# C.A. 2673           2
# 347054              2
# A/4 48871           2
# C.A. 37671          2
# 2653                2
# 364849              2
# 364516              2
#                    ..
# PP 4348             1
# 349245              1
# 347061              1
# 312991              1
# 349206              1
# 350035              1
# A/S 2816            1
# 342826              1
# 2697                1
# 2667                1
# ...

# %%
t.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 0.0000      15
# 7.2292      15
# 26.5500     15
# 8.6625      13
# 7.2500      13
# 7.8542      13
# 7.2250      12
# 16.1000      9
# 9.5000       9
# 24.1500      8
# 15.5000      8
# 31.2750      7
# 14.5000      7
# 52.0000      7
# 14.4542      7
# 7.0500       7
# 56.4958      7
# 69.5500      7
# 46.9000      6
# 26.2500      6
# 30.0000      6
# 27.9000      6
#             ..
# 8.3000       1
# 8.7125       1
# 34.0208      1
# 26.2833      1
# 6.9500       1
# 50.4958      1
# 28.7125      1
# 51.4792      1
# 8.4583       1
# 42.4000      1
# 8.6833       1
# 39.4000      1
# 8.5167       1
# 55.4417      1
# 61.3792      1
# 6.4375       1
# 12.0000      1
# 61.1750      1
# 7.1417       1
# 211.5000     1
# 7.3125       1
# 14.0000      1
# 15.7500      1
# 59.4000      1
# 10.5167      1
# 26.3875      1
# 8.1583       1
# ...

# %%
t[t.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Histogram of Fare
t.Fare.hist(bins=5)

# %%
t.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   23.882727    0.523008
# std     257.353842    0.486592    0.836071   17.483538    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000    6.000000    0.000000
# 50%     446.000000    0.000000    3.000000   24.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # EDA for Cabin Variable

# %%
t.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# C22 C26            3
# D                  3
# F33                3
# E101               3
# F2                 3
# C2                 2
# F G73              2
# E8                 2
# E44                2
# B57 B59 B63 B66    2
# B58 B60            2
# C52                2
# D33                2
# E25                2
# C92                2
# E24                2
# D20                2
# B35                2
# C126               2
# D17                2
# D35                2
# B18                2
# B5                 2
# E121               2
# C68                2
# B51 B53 B55        2
# E33                2
#                   ..
# C86                1
# E46                1
# A14                1
# C106               1
# B41                1
# B50                1
# D30                1
# C101               1
# E50                1
# A5                 1
# A31                1
# D19                1
# ...

# %%
len(set(t.Cabin))
# Out:
# 148

# %%
# Finding Missing Values
t[t.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
t.Cabin.value_counts().plot(kind='bar')

# %%
t.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#Finding Null Value

t[t.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
t.Embarked.value_counts().plot(kind='bar')

# %%
#Variable Embarked is categorized in three values 'S','C','Q'.Therefore Embarked is categorical.
